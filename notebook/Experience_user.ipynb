# %%
import sys
sys.path.insert(0, '/10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo/')

# %%
from scripts.Experience_user import User_Experience
from scripts.db_conn import DataLoader
from scripts.Basic_info import EDA

# %%
load = DataLoader()

# %%
df = load.fetch_data()
# Out:
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\db_conn.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, self.conn)

# %%
basic= EDA(df)

# %%
exp = User_Experience(df)

# %%
df
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000           NaN             None       NaN             None     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
basic.missing_percentage()
# Out:
#                                                                             Column  \
# Nb of sec with 37500B < Vol UL                      Nb of sec with 37500B < Vol UL
# Nb of sec with 6250B < Vol UL < 37500B      Nb of sec with 6250B < Vol UL < 37500B
# Nb of sec with 125000B < Vol DL                    Nb of sec with 125000B < Vol DL
# TCP UL Retrans. Vol (Bytes)                            TCP UL Retrans. Vol (Bytes)
# Nb of sec with 31250B < Vol DL < 125000B  Nb of sec with 31250B < Vol DL < 125000B
# Nb of sec with 1250B < Vol UL < 6250B        Nb of sec with 1250B < Vol UL < 6250B
# Nb of sec with 6250B < Vol DL < 31250B      Nb of sec with 6250B < Vol DL < 31250B
# TCP DL Retrans. Vol (Bytes)                            TCP DL Retrans. Vol (Bytes)
# HTTP UL (Bytes)                                                    HTTP UL (Bytes)
# HTTP DL (Bytes)                                                    HTTP DL (Bytes)
# ...

# %%
exp.handle_missing_values()
# Out:
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[col].fillna(mean_value, inplace=True)
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
basic.missing_percentage()
# Out:
#                                                                             Column  \
# Nb of sec with 37500B < Vol UL                      Nb of sec with 37500B < Vol UL
# Nb of sec with 6250B < Vol UL < 37500B      Nb of sec with 6250B < Vol UL < 37500B
# Nb of sec with 125000B < Vol DL                    Nb of sec with 125000B < Vol DL
# Nb of sec with 31250B < Vol DL < 125000B  Nb of sec with 31250B < Vol DL < 125000B
# Nb of sec with 1250B < Vol UL < 6250B        Nb of sec with 1250B < Vol UL < 6250B
# Nb of sec with 6250B < Vol DL < 31250B      Nb of sec with 6250B < Vol DL < 31250B
# HTTP UL (Bytes)                                                    HTTP UL (Bytes)
# HTTP DL (Bytes)                                                    HTTP DL (Bytes)
# Last Location Name                                              Last Location Name
# MSISDN/Number                                                        MSISDN/Number
# ...

# %%
basic.outlier_check_perc()
# Out:
#                                                                             Column  \
# DL TP > 1 Mbps (%)                                              DL TP > 1 Mbps (%)
# 10 Kbps < UL TP < 50 Kbps (%)                        10 Kbps < UL TP < 50 Kbps (%)
# 250 Kbps < DL TP < 1 Mbps (%)                        250 Kbps < DL TP < 1 Mbps (%)
# HTTP DL (Bytes)                                                    HTTP DL (Bytes)
# Activity Duration DL (ms)                                Activity Duration DL (ms)
# Activity Duration UL (ms)                                Activity Duration UL (ms)
# Nb of sec with Vol UL < 1250B                        Nb of sec with Vol UL < 1250B
# Nb of sec with Vol DL < 6250B                        Nb of sec with Vol DL < 6250B
# MSISDN/Number                                                        MSISDN/Number
# HTTP UL (Bytes)                                                    HTTP UL (Bytes)
# ...

# %%
exp.handle_outliers()
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000           NaN             None       NaN             None     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
basic.outlier_check_perc()
# Out:
#                                                                             Column  \
# DL TP > 1 Mbps (%)                                              DL TP > 1 Mbps (%)
# 10 Kbps < UL TP < 50 Kbps (%)                        10 Kbps < UL TP < 50 Kbps (%)
# 250 Kbps < DL TP < 1 Mbps (%)                        250 Kbps < DL TP < 1 Mbps (%)
# Avg Bearer TP UL (kbps)                                    Avg Bearer TP UL (kbps)
# HTTP DL (Bytes)                                                    HTTP DL (Bytes)
# Avg Bearer TP DL (kbps)                                    Avg Bearer TP DL (kbps)
# Activity Duration DL (ms)                                Activity Duration DL (ms)
# Activity Duration UL (ms)                                Activity Duration UL (ms)
# Nb of sec with Vol UL < 1250B                        Nb of sec with Vol UL < 1250B
# Nb of sec with Vol DL < 6250B                        Nb of sec with Vol DL < 6250B
# ...

# %%
df
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000           NaN             None       NaN             None     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
exp.aggregate_per_customer()
# Out:
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[col].fillna(mean_value, inplace=True)
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
exp.plot_aggregated_data()
# Out:
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[col].fillna(mean_value, inplace=True)
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
exp.plot_top_bottom()
# Out:
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[col].fillna(mean_value, inplace=True)
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
exp.compute_avg_throughput_per_handset()
# Out:
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[col].fillna(mean_value, inplace=True)
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
exp.visualize_avg_throughput()
# Out:
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[col].fillna(mean_value, inplace=True)
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
exp.compute_avg_tcp_retransmission_per_handset()
# Out:
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[col].fillna(mean_value, inplace=True)
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
exp.visualize_avg_tcp_retransmission()
# Out:
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[col].fillna(mean_value, inplace=True)
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
exp.cluster_user_exp_metrics()
# Out:
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[col].fillna(mean_value, inplace=True)
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
exp.describe_clusters()
# Out:
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[col].fillna(mean_value, inplace=True)
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
exp.visualize_clusters()
# Out:
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[col].fillna(mean_value, inplace=True)
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\Experience_user.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...
