# %%
import sys
sys.path.insert(0, '/10 A KAI 2/Week 2/EDA_TellCo/')

# %%
from scripts.Basic_info import EDA
from scripts.db_conn import DataLoader
from scripts.customer_seg import User_Overview

# %%
load = DataLoader()

# %%
df = load.fetch_data()
# Out:
# d:\10 A KAI 2/Week 2/EDA_TellCo\scripts\db_conn.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, self.conn)

# %%
res = User_Overview(df)

# %%
res.User_seg()
# Out:
#                 IMSI  total_duration     total_DL    total_UL  \
# 0       2.040471e+14        869844.0   78697597.0  60456049.0
# 1       2.040808e+14        877385.0  194828056.0  37295915.0
# 2       2.082001e+14         86019.0   31376981.0  53794658.0
# 3       2.082001e+14         86254.0  392918313.0  33583272.0
# 4       2.082001e+14        573923.0  961767023.0  71325004.0
# ...              ...             ...          ...         ...
# 107260  2.082099e+14        127367.0  688815403.0  33888182.0
# 107261  2.082099e+14        168543.0  451173021.0  44692550.0
# 107262  2.082099e+14         86399.0  307825104.0  30355487.0
# 107263  2.082522e+14         56613.0  800629358.0  45083854.0
# 107264  2.140743e+14        226790.0  637123579.0  57382080.0
#
#         Total Data (Bytes)  Decile
# 0             1.391536e+08       9
# 1             2.321240e+08       9
# 2             8.517164e+07       3
# 3             4.265016e+08       3
# 4             1.033092e+09       9
# ...                    ...     ...
# 107260        7.227036e+08       5
# 107261        4.958656e+08       7
# 107262        3.381806e+08       3
# 107263        8.457132e+08       2
# 107264        6.945057e+08       8
#
# [107265 rows x 6 columns]

# %%
res.plot_insights()

# %%
res.non_graphical_univariate_analysis()
# Out:
# Analysis for Dur. (ms):
# Mean: 104608.56034666667
# Median: 86399.0
# Mode: 86399.0
# Standard Deviation: 81037.62147900184
# Variance: 6567096094.97398
# Interquartile Range: 74989.75
# Min: 7142.0
# Max: 1859336.0
# Missing values: 0 / 150000
# ==================================================
# Analysis for Social Media DL (Bytes):
# Mean: 1795321.7736466667
# Median: 1794351.0
# Mode: 152013.0
# Standard Deviation: 1035485.727577847
# Variance: 1072230692017.4231
# Interquartile Range: 1795794.0
# Min: 12.0
# Max: 3586064.0
# Missing values: 0 / 150000
# ==================================================
# Analysis for Social Media UL (Bytes):
# Mean: 32928.43438
# Median: 32920.0
# Mode: 30810.0
# Standard Deviation: 19006.241610457382
# Variance: 361237220.1550816
# Interquartile Range: 32886.0
# Min: 0.0
# Max: 65870.0
# Missing values: 0 / 150000
# ==================================================
# Analysis for Netflix DL (Bytes):
# Mean: 11626851.71874
# Median: 11642220.0
# Mode: 2097111.0
# Standard Deviation: 6725240.443999067
# Variance: 45228859029600.766
# Interquartile Range: 11693409.0
# Min: 42.0
# Max: 23259189.0
# Missing values: 0 / 150000
# ==================================================
# Analysis for Netflix UL (Bytes):
# Mean: 11001754.81964
# Median: 10996306.0
# Mode: 1751610.0
# Standard Deviation: 6359510.957879756
# Variance: 40443379623392.69
# Interquartile Range: 11031313.0
# Min: 35.0
# Max: 22011955.0
# Missing values: 0 / 150000
# ==================================================
# Analysis for Google DL (Bytes):
# Mean: 5750752.619286667
# Median: 5765857.0
# Mode: 3991481.0
# Standard Deviation: 3309108.047747226
# Variance: 10950196071665.457
# Interquartile Range: 5741198.75
# Min: 207.0
# Max: 11462832.0
# Missing values: 0 / 150000
# ==================================================
# Analysis for Google UL (Bytes):
# Mean: 2056541.9262866667
# Median: 2054569.0
# Mode: 3426526.0
# Standard Deviation: 1189920.892413687
# Variance: 1415911730202.5854
# Interquartile Range: 2064179.75
# Min: 3.0
# Max: 4121357.0
# Missing values: 0 / 150000
# ==================================================
# Analysis for Email DL (Bytes):
# Mean: 1791728.86802
# Median: 1793534.0
# Mode: 1829513.0
# Standard Deviation: 1035842.963152453
# Variance: 1072970644312.454
# Interquartile Range: 1796548.0
# Min: 14.0
# Max: 3586146.0
# Missing values: 0 / 150000
# ==================================================
# Analysis for Email UL (Bytes):
# Mean: 467373.44194
# Median: 466246.0
# Mode: 53137.0
# Standard Deviation: 269970.20693321177
# Variance: 72883912631.56119
# Interquartile Range: 467061.75
# Min: 2.0
# Max: 936418.0
# Missing values: 0 / 150000
# ==================================================
# Analysis for Gaming DL (Bytes):
# Mean: 422044702.59537333
# Median: 423408228.0
# Mode: 88731721.0
# Standard Deviation: 243968307.57542554
# Variance: 5.952053510121743e+16
# Interquartile Range: 422704037.75
# Min: 2516.0
# Max: 843441889.0
# Missing values: 0 / 150000
# ==================================================
# Analysis for Gaming UL (Bytes):
# Mean: 8288398.110733333
# Median: 8291215.0
# Mode: 15304673.0
# Standard Deviation: 4782715.598643469
# Variance: 22874368497507.55
# Interquartile Range: 8303204.0
# Min: 59.0
# Max: 16558794.0
# Missing values: 0 / 150000
# ==================================================
# Analysis for Other DL (Bytes):
# Mean: 421100544.19449335
# Median: 421805747.5
# Mode: 28616268.0
# Standard Deviation: 243205820.4955745
# Variance: 5.914907112292561e+16
# Interquartile Range: 421512586.25
# Min: 3290.0
# Max: 843442489.0
# Missing values: 0 / 150000
# ==================================================
# Analysis for Other UL (Bytes):
# Mean: 8264799.424426666
# Median: 8267086.5
# Mode: 4514572.0
# Standard Deviation: 4769019.583161553
# Variance: 22743547784578.4
# Interquartile Range: 8238293.25
# Min: 148.0
# Max: 16558816.0
# Missing values: 0 / 150000
# ==================================================

# %%
res.graphical_univariate_analysis()

# %%
res.bivariate_analysis()

# %%
res.correlation_analysis()

# %%
res.dimensionality_reduction()
# Out:
# array([0.16845693, 0.16726614])

# %%
res.calculate_engagement_metrics()
# Out:
#                 IMSI  Session Frequency  Total Duration (ms)  \
# 0       2.040471e+14                  1             869844.0
# 1       2.040808e+14                  1             877385.0
# 2       2.082001e+14                  1              86019.0
# 3       2.082001e+14                  1              86254.0
# 4       2.082001e+14                  2             573923.0
# ...              ...                ...                  ...
# 107260  2.082099e+14                  1             127367.0
# 107261  2.082099e+14                  1             168543.0
# 107262  2.082099e+14                  1              86399.0
# 107263  2.082522e+14                  1              56613.0
# 107264  2.140743e+14                  1             226790.0
#
#         Total Traffic (Bytes)
# 0                1.391536e+08
# 1                2.321240e+08
# 2                8.517164e+07
# 3                4.265016e+08
# 4                1.033092e+09
# ...                       ...
# 107260           7.227036e+08
# 107261           4.958656e+08
# 107262           3.381806e+08
# 107263           8.457132e+08
# 107264           6.945057e+08
#
# [107265 rows x 4 columns]
