# %%
import sys
sys.path.insert(0, '/10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo/')

# %%
from scripts.Basic_info import EDA
from scripts.db_conn import DataLoader
from scripts.Customer_seg import User_Overview
from scripts.user_engagment import User_Engagement

# %%
load = DataLoader()

# %%
df = load.fetch_data()
# Out:
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\db_conn.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, self.conn)

# %%
res = User_Engagement(df)

# %%
df
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000           NaN             None       NaN             None     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
res.calculate_engagement_metrics()
# Out:
#         MSISDN/Number  Session Frequency  Total Duration (ms)  \
# 0        3.360100e+10                  1             116720.0
# 1        3.360100e+10                  1             181230.0
# 2        3.360100e+10                  1             134969.0
# 3        3.360101e+10                  1              49878.0
# 4        3.360101e+10                  2              37104.0
# ...               ...                ...                  ...
# 106466   3.379000e+10                  1               8810.0
# 106467   3.379000e+10                  1             140988.0
# 106468   3.197021e+12                  1             877385.0
# 106469   3.370000e+14                  1             253030.0
# 106470   8.823971e+14                  1             869844.0
#
#         Total Traffic (Bytes)
# 0                8.786906e+08
# 1                1.568596e+08
# 2                5.959665e+08
# 3                4.223207e+08
# 4                1.457411e+09
# ...                       ...
# ...

# %%
res.plot_aggre_matrix()

# %%
res.report_top_10_customers()
# Out:
# Top 10 Customers by Session Frequency:
#         MSISDN/Number  Session Frequency
# 13467   3.362632e+10                 18
# 6404    3.361489e+10                 17
# 13123   3.362578e+10                 17
# 36909   3.365973e+10                 16
# 76077   3.367588e+10                 15
# 92584   3.376054e+10                 15
# 64883   3.366716e+10                 13
# 658     3.360313e+10                 12
# 1270    3.360452e+10                 12
# 13934   3.362708e+10                 12
#
# Top 10 Customers by Total Duration:
#         MSISDN/Number  Total Duration (ms)
# 13123   3.362578e+10           18553754.0
# 6404    3.361489e+10            9966898.0
# 92584   3.376054e+10            9279434.0
# 13467   3.362632e+10            8791927.0
# 64883   3.366716e+10            8744914.0
# 50096   3.366284e+10            6614270.0
# 56951   3.366469e+10            6288730.0
# 658     3.360313e+10            6287761.0
# 65787   3.366746e+10            5649882.0
# ...

# %%
res.plot_top_10_customers()

# %%
res.k_means_clustering()
# Out:
#         MSISDN/Number  Session Frequency  Total Duration (ms)  \
# 0        3.360100e+10                  1             116720.0
# 1        3.360100e+10                  1             181230.0
# 2        3.360100e+10                  1             134969.0
# 3        3.360101e+10                  1              49878.0
# 4        3.360101e+10                  2              37104.0
# ...               ...                ...                  ...
# 106466   3.379000e+10                  1               8810.0
# 106467   3.379000e+10                  1             140988.0
# 106468   3.197021e+12                  1             877385.0
# 106469   3.370000e+14                  1             253030.0
# 106470   8.823971e+14                  1             869844.0
#
#         Total Traffic (Bytes)  cluster
# 0                8.786906e+08        1
# 1                1.568596e+08        1
# 2                5.959665e+08        1
# 3                4.223207e+08        1
# ...

# %%
res.compute_cluster_stats()
# Out:
#          min_sessions_frequency  max_sessions_frequency  \
# cluster
# 0                             1                       7
# 1                             1                       2
# 2                             2                      18
#
#          avg_sessions_frequency  total_sessions_frequency  min_duration  \
# cluster
# 0                      2.481103                     55078       18235.0
# 1                      1.076108                     90067        7142.0
# 2                      5.845217                      3361      422051.0
#
#          max_duration  avg_duration  total_duration  min_traffic  \
# cluster
# 0           1573420.0  2.592680e+05    5.755491e+09  177006936.0
# 1           1042254.0  1.064396e+05    8.908675e+09   33249009.0
# 2          18553754.0  1.637300e+06    9.414474e+08  542935647.0
#
#           max_traffic   avg_traffic  total_traffic
# cluster
# 0        4.032163e+09  1.336827e+09   2.967622e+13
# ...

# %%
res.aggregate_traffic_per_application()
# Out:
#         MSISDN/Number  Total Youtube Traffic  Total Social Media Traffic  \
# 0        3.360100e+10             21624548.0                   2232135.0
# 1        3.360100e+10             12432223.0                   2660565.0
# 2        3.360100e+10             21333570.0                   3195623.0
# 3        3.360101e+10              6977321.0                    280294.0
# 4        3.360101e+10             41533002.0                   2912542.0
# ...               ...                    ...                         ...
# 106466   3.379000e+10             26647843.0                    300183.0
# 106467   3.379000e+10             19851572.0                    498569.0
# 106468   3.197021e+12             11959905.0                    715224.0
# 106469   3.370000e+14             36734940.0                    521566.0
# 106470   8.823971e+14             40940710.0                   1546088.0
#
#         Total Netflix Traffic  Total Google Traffic  Total Gaming Traffic  \
# ...

# %%
res.top_10_users_per_application()
# Out:
# Top 10 Most Engaged Users on YouTube:
#         MSISDN/Number  Total Youtube Traffic
# 13123   3.362578e+10            452958769.0
# 92584   3.376054e+10            396289198.0
# 6404    3.361489e+10            394370218.0
# 13467   3.362632e+10            374483047.0
# 76077   3.367588e+10            317410572.0
# 64883   3.366716e+10            315231310.0
# 13934   3.362708e+10            308790774.0
# 92239   3.376041e+10            303169107.0
# 86138   3.369879e+10            302661958.0
# 658     3.360313e+10            284090139.0
#
# Top 10 Most Engaged Users on Social Media:
#          MSISDN/Number  Total Social Media Traffic
# 13467    3.362632e+10                  43374779.0
# 92584    3.376054e+10                  39783189.0
# 36909    3.365973e+10                  35412358.0
# 6404     3.361489e+10                  28294544.0
# 13123    3.362578e+10                  27135500.0
# 64883    3.366716e+10                  24247850.0
# ...

# %%
res.plot_top_3_applications()

# %%
res.elbow_method()
