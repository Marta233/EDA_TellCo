# %%
import sys
sys.path.insert(0, '/10 A KAI 2/Week 2/EDA_TellCo/')

# %% [markdown]
# #### Task 1.2 load data and made preprocess

# %%
from scripts.Basic_info import EDA
from scripts.db_conn import DataLoader

# %%
load = DataLoader()

# %%
df = load.fetch_data()
# Out:
# d:\10 A KAI 2/Week 2/EDA_TellCo\scripts\db_conn.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, self.conn)

# %%
res = EDA(df)

# %%
df
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000           NaN             None       NaN             None     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
df.columns
# Out:
# Index(['Bearer Id', 'Start', 'Start ms', 'End', 'End ms', 'Dur. (ms)', 'IMSI',
#        'MSISDN/Number', 'IMEI', 'Last Location Name', 'Avg RTT DL (ms)',
#        'Avg RTT UL (ms)', 'Avg Bearer TP DL (kbps)', 'Avg Bearer TP UL (kbps)',
#        'TCP DL Retrans. Vol (Bytes)', 'TCP UL Retrans. Vol (Bytes)',
#        'DL TP < 50 Kbps (%)', '50 Kbps < DL TP < 250 Kbps (%)',
#        '250 Kbps < DL TP < 1 Mbps (%)', 'DL TP > 1 Mbps (%)',
#        'UL TP < 10 Kbps (%)', '10 Kbps < UL TP < 50 Kbps (%)',
#        '50 Kbps < UL TP < 300 Kbps (%)', 'UL TP > 300 Kbps (%)',
#        'HTTP DL (Bytes)', 'HTTP UL (Bytes)', 'Activity Duration DL (ms)',
#        'Activity Duration UL (ms)', 'Dur. (ms).1', 'Handset Manufacturer',
#        'Handset Type', 'Nb of sec with 125000B < Vol DL',
#        'Nb of sec with 1250B < Vol UL < 6250B',
#        'Nb of sec with 31250B < Vol DL < 125000B',
#        'Nb of sec with 37500B < Vol UL',
#        'Nb of sec with 6250B < Vol DL < 31250B',
# ...

# %%
if 'YouTube DL (Bytes)' in df.columns and 'YouTube UL (Bytes)' in df.columns:
    df['Total YouTube Traffic'] = df['YouTube DL (Bytes)'] + df['YouTube UL (Bytes)']
else:
    print("YouTube columns are missing from the dataset")
# Out:
# YouTube columns are missing from the dataset

# %%
res.missing_percentage()
# Out:
#                                                                             Column  \
# Nb of sec with 37500B < Vol UL                      Nb of sec with 37500B < Vol UL
# Nb of sec with 6250B < Vol UL < 37500B      Nb of sec with 6250B < Vol UL < 37500B
# Nb of sec with 125000B < Vol DL                    Nb of sec with 125000B < Vol DL
# TCP UL Retrans. Vol (Bytes)                            TCP UL Retrans. Vol (Bytes)
# Nb of sec with 31250B < Vol DL < 125000B  Nb of sec with 31250B < Vol DL < 125000B
# Nb of sec with 1250B < Vol UL < 6250B        Nb of sec with 1250B < Vol UL < 6250B
# Nb of sec with 6250B < Vol DL < 31250B      Nb of sec with 6250B < Vol DL < 31250B
# TCP DL Retrans. Vol (Bytes)                            TCP DL Retrans. Vol (Bytes)
# HTTP UL (Bytes)                                                    HTTP UL (Bytes)
# HTTP DL (Bytes)                                                    HTTP DL (Bytes)
# ...

# %%
## remove >50% missing values
res.remove_columns()
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000           NaN             None       NaN             None     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
res.data_types()
# Out:
#                                                         Column data_typs
# Start                                                    Start    object
# Handset Type                                      Handset Type    object
# End                                                        End    object
# Handset Manufacturer                      Handset Manufacturer    object
# Email UL (Bytes)                              Email UL (Bytes)   float64
# Nb of sec with Vol DL < 6250B    Nb of sec with Vol DL < 6250B   float64
# Nb of sec with Vol UL < 1250B    Nb of sec with Vol UL < 1250B   float64
# Social Media DL (Bytes)                Social Media DL (Bytes)   float64
# Social Media UL (Bytes)                Social Media UL (Bytes)   float64
# Google DL (Bytes)                            Google DL (Bytes)   float64
# Google UL (Bytes)                            Google UL (Bytes)   float64
# Email DL (Bytes)                              Email DL (Bytes)   float64
# ...

# %%
df
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000           NaN             None       NaN             None     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
res.remove_columns()
# Out:
# ...
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000           NaN             None       NaN             None     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
res.basic_info1()
# Out:
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 42 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Bearer Id                       149010 non-null  float64
#  1   Start                           150000 non-null  object
#  2   Start ms                        150000 non-null  float64
#  3   End                             150000 non-null  object
#  4   End ms                          150000 non-null  float64
#  5   Dur. (ms)                       150000 non-null  float64
#  6   IMSI                            149431 non-null  float64
#  7   MSISDN/Number                   148935 non-null  float64
#  8   IMEI                            149429 non-null  float64
#  9   Avg Bearer TP DL (kbps)         150000 non-null  float64
#  10  Avg Bearer TP UL (kbps)         150000 non-null  float64
# ...

# %%
res.outlier_check_perc()
# Out:
#                                                         Column  \
# DL TP > 1 Mbps (%)                          DL TP > 1 Mbps (%)
# 10 Kbps < UL TP < 50 Kbps (%)    10 Kbps < UL TP < 50 Kbps (%)
# 250 Kbps < DL TP < 1 Mbps (%)    250 Kbps < DL TP < 1 Mbps (%)
# Activity Duration DL (ms)            Activity Duration DL (ms)
# Activity Duration UL (ms)            Activity Duration UL (ms)
# Nb of sec with Vol UL < 1250B    Nb of sec with Vol UL < 1250B
# Nb of sec with Vol DL < 6250B    Nb of sec with Vol DL < 6250B
# MSISDN/Number                                    MSISDN/Number
# UL TP < 10 Kbps (%)                        UL TP < 10 Kbps (%)
# Avg Bearer TP UL (kbps)                Avg Bearer TP UL (kbps)
# DL TP < 50 Kbps (%)                        DL TP < 50 Kbps (%)
# 50 Kbps < DL TP < 250 Kbps (%)  50 Kbps < DL TP < 250 Kbps (%)
# IMSI                                                      IMSI
# Avg Bearer TP DL (kbps)                Avg Bearer TP DL (kbps)
# ...

# %%
res.data_types()
# Out:
#                                                         Column data_typs
# Start                                                    Start    object
# Handset Type                                      Handset Type    object
# End                                                        End    object
# Handset Manufacturer                      Handset Manufacturer    object
# Email UL (Bytes)                              Email UL (Bytes)   float64
# Nb of sec with Vol DL < 6250B    Nb of sec with Vol DL < 6250B   float64
# Nb of sec with Vol UL < 1250B    Nb of sec with Vol UL < 1250B   float64
# Social Media DL (Bytes)                Social Media DL (Bytes)   float64
# Social Media UL (Bytes)                Social Media UL (Bytes)   float64
# Google DL (Bytes)                            Google DL (Bytes)   float64
# Google UL (Bytes)                            Google UL (Bytes)   float64
# Email DL (Bytes)                              Email DL (Bytes)   float64
# ...

# %%
res.summary_statistics()
# Out:
#           Bearer Id       Start ms         End ms     Dur. (ms)          IMSI  \
# count  1.490100e+05  150000.000000  150000.000000  1.500000e+05  1.494310e+05
# mean   1.013887e+19     499.188200     498.800880  1.046086e+05  2.082016e+14
# std    2.893173e+18     288.611834     288.097653  8.103762e+04  2.148809e+10
# min    6.917538e+18       0.000000       0.000000  7.142000e+03  2.040471e+14
# 25%    7.349883e+18     250.000000     251.000000  5.744050e+04  2.082014e+14
# 50%    7.349883e+18     499.000000     500.000000  8.639900e+04  2.082015e+14
# 75%    1.304243e+19     749.000000     750.000000  1.324302e+05  2.082018e+14
# max    1.318654e+19     999.000000     999.000000  1.859336e+06  2.140743e+14
#
#        MSISDN/Number          IMEI  Avg Bearer TP DL (kbps)  \
# count   1.489350e+05  1.494290e+05            150000.000000
# mean    4.188282e+10  4.847455e+13             13300.045927
# std     2.447443e+12  2.241637e+13             23971.878541
# ...

# %%
res.stast_some_col1()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 res.stast_some_col1()
#
# AttributeError: 'EDA' object has no attribute 'stast_some_col1'
