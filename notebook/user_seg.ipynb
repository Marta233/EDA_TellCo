# %%
import sys
sys.path.insert(0, '/10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo/')

# %%
from scripts.Basic_info import EDA
from scripts.db_conn import DataLoader
from scripts.Customer_seg import User_Overview

# %%
load = DataLoader()

# %%
df = load.fetch_data()
# Out:
# d:\10 A KAI 2/Week 2/EDA_TellCo/EDA_TellCo\scripts\db_conn.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, self.conn)

# %%
res = User_Overview(df)

# %%
res.segment_and_compute_data()

# %%
res.non_graphical_univariate_analysis()
# Out:
# Analysis for Dur. (ms):
# Mean: 104755.88472940688
# Median: 86399.0
# Mode: 86399.0
# Standard Deviation: 81056.23809938651
# Variance: 6570113734.824436
# Interquartile Range: 74913.5
# Min: 7142.0
# Max: 1859336.0
# Missing values: 0 / 149431
# ==================================================
# Analysis for Social Media DL (Bytes):
# Mean: 1795250.694387376
# Median: 1794180.0
# Mode: 152013.0
# Standard Deviation: 1035514.8202822154
# Variance: 1072290943024.1088
# Interquartile Range: 1796010.0
# Min: 12.0
# Max: 3586064.0
# Missing values: 0 / 149431
# ==================================================
# Analysis for Social Media UL (Bytes):
# Mean: 32924.95618044449
# Median: 32917.0
# Mode: 30810.0
# Standard Deviation: 19007.943073322782
# Variance: 361301899.87867945
# Interquartile Range: 32890.5
# Min: 0.0
# Max: 65870.0
# Missing values: 0 / 149431
# ==================================================
# Analysis for Netflix DL (Bytes):
# Mean: 11626145.188073425
# Median: 11639912.0
# Mode: 2097111.0
# Standard Deviation: 6724616.804464077
# Variance: 45220471166880.65
# Interquartile Range: 11690372.0
# Min: 42.0
# Max: 23259189.0
# Missing values: 0 / 149431
# ==================================================
# Analysis for Netflix UL (Bytes):
# Mean: 11000918.416640457
# Median: 10995869.0
# Mode: 1751610.0
# Standard Deviation: 6359521.587745348
# Variance: 40443514824999.12
# Interquartile Range: 11031091.0
# Min: 35.0
# Max: 22011955.0
# Missing values: 0 / 149431
# ==================================================
# Analysis for Google DL (Bytes):
# Mean: 5751252.04383294
# Median: 5766409.0
# Mode: 3991481.0
# Standard Deviation: 3309415.9690477443
# Variance: 10952234056188.22
# Interquartile Range: 5742897.5
# Min: 207.0
# Max: 11462832.0
# Missing values: 0 / 149431
# ==================================================
# Analysis for Google UL (Bytes):
# Mean: 2056478.2730424076
# Median: 2054606.0
# Mode: 3426526.0
# Standard Deviation: 1189941.3963673154
# Variance: 1415960526788.5964
# Interquartile Range: 2064516.0
# Min: 3.0
# Max: 4121357.0
# Missing values: 0 / 149431
# ==================================================
# Analysis for Email DL (Bytes):
# Mean: 1791615.7734807369
# Median: 1793161.0
# Mode: 1829513.0
# Standard Deviation: 1035805.4860139397
# Variance: 1072893004856.574
# Interquartile Range: 1796515.0
# Min: 14.0
# Max: 3586146.0
# Missing values: 0 / 149431
# ==================================================
# Analysis for Email UL (Bytes):
# Mean: 467399.1405665491
# Median: 466289.0
# Mode: 53137.0
# Standard Deviation: 269969.3647215673
# Variance: 72883457888.16663
# Interquartile Range: 467033.5
# Min: 2.0
# Max: 936418.0
# Missing values: 0 / 149431
# ==================================================
# Analysis for Gaming DL (Bytes):
# Mean: 422051089.82919204
# Median: 423447372.0
# Mode: 88731721.0
# Standard Deviation: 243968800.1695622
# Variance: 5.952077545617577e+16
# Interquartile Range: 422621525.0
# Min: 2516.0
# Max: 843441889.0
# Missing values: 0 / 149431
# ==================================================
# Analysis for Gaming UL (Bytes):
# Mean: 8289462.024151615
# Median: 8291348.0
# Mode: 15304673.0
# Standard Deviation: 4781989.727451358
# Variance: 22867425753450.312
# Interquartile Range: 8301611.0
# Min: 59.0
# Max: 16558794.0
# Missing values: 0 / 149431
# ==================================================
# Analysis for Other DL (Bytes):
# Mean: 421139825.0710495
# Median: 421844919.0
# Mode: 28616268.0
# Standard Deviation: 243204445.2160948
# Variance: 5.914840217286845e+16
# Interquartile Range: 421449554.5
# Min: 3290.0
# Max: 843442489.0
# Missing values: 0 / 149431
# ==================================================
# Analysis for Other UL (Bytes):
# Mean: 8263602.096693457
# Median: 8266907.0
# Mode: 4514572.0
# Standard Deviation: 4768136.981069833
# Variance: 22735130270245.742
# Interquartile Range: 8235004.0
# Min: 148.0
# Max: 16558816.0
# Missing values: 0 / 149431
# ==================================================

# %%
res.graphical_univariate_analysis()

# %%
res.bivariate_analysis()

# %%
res.correlation_analysis()

# %%
res.dimensionality_reduction()
# Out:
# array([0.16845693, 0.16726614])

# %%
res.calculate_engagement_metrics()
# Out:
#                 IMSI  Session Frequency  Total Duration (ms)  \
# 0       2.040471e+14                  1             869844.0
# 1       2.040808e+14                  1             877385.0
# 2       2.082001e+14                  1              86019.0
# 3       2.082001e+14                  1              86254.0
# 4       2.082001e+14                  2             573923.0
# ...              ...                ...                  ...
# 107260  2.082099e+14                  1             127367.0
# 107261  2.082099e+14                  1             168543.0
# 107262  2.082099e+14                  1              86399.0
# 107263  2.082522e+14                  1              56613.0
# 107264  2.140743e+14                  1             226790.0
#
#         Total Traffic (Bytes)
# 0                1.391536e+08
# 1                2.321240e+08
# 2                8.517164e+07
# 3                4.265016e+08
# 4                1.033092e+09
# ...                       ...
# 107260           7.227036e+08
# 107261           4.958656e+08
# 107262           3.381806e+08
# 107263           8.457132e+08
# 107264           6.945057e+08
#
# [107265 rows x 4 columns]
